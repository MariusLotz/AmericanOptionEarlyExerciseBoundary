# %% [markdown]
# <a href="https://colab.research.google.com/github/MariusLotz/AmericanOptionEarlyExerciseBoundary/blob/ML/Training_3_11_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Github/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Github

# %%
usr = "MariusLotz"
rep = "AmericanOptionEarlyExerciseBoundary"
token = "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"

# !git clone https://{token}@github.com/{usr}/{rep}
# !cd ML && git checkout ML
# !git branch
# Out:
# fatal: destination path 'AmericanOptionEarlyExerciseBoundary' already exists and is not an empty directory.
# /bin/bash: line 0: cd: ML: No such file or directory
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
import tensorflow as tf


def main():
    dest_file = \
        '/content/drive/MyDrive/Github/AmericanOptionEarlyExerciseBoundary/ML/Small_Sample_3_11'
    file = open(dest_file, 'r')
    x_list = []
    fx_list = []
    count = 0
    while True:
        line = file.readline()
        count += 1
        if not line:
            break
        try:
            xline = eval(line)
        except:
            continue

        x = [xline[0],  # r
             xline[1],  # q
             xline[2]]  # sigma
        x_list.append(x)

        fx_list.append(xline[3]) # exercise boundary (10,1)
    file.close()


    """Creating Modell"""
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(1024, input_shape=(3,), activation='relu'))
    model.add(tf.keras.layers.Dense(512, activation='relu'))
    model.add(tf.keras.layers.Dense(256, activation='relu'))
    model.add(tf.keras.layers.Dense(10, activation='linear'))
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', min_delta=10 ** (-6), patience=10, verbose=0,
        mode='auto', baseline=None, restore_best_weights=True)
    model.compile(optimizer='adam', loss='log_cosh', metrics='mean_absolute_percentage_error')
    nepoch = 2999
    nbatch = 64
    model.fit(x_list, fx_list, epochs=nepoch, batch_size=nbatch)
    
    model.save("/content/drive/MyDrive/Github/AmericanOptionEarlyExerciseBoundary/ML/NN_of_Small_Sample_3_11")

if __name__=="__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2493 - mean_absolute_percentage_error: 0.3339
# Epoch 7501/9999
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2046 - mean_absolute_percentage_error: 0.2730
# Epoch 7502/9999
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1373 - mean_absolute_percentage_error: 0.2261
# Epoch 7503/9999
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1315 - mean_absolute_percentage_error: 0.2007
# Epoch 7504/9999
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2216 - mean_absolute_percentage_error: 0.2671
# Epoch 7505/9999
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1477 - mean_absolute_percentage_error: 0.2209
# Epoch 7506/9999
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3725 - mean_absolute_percentage_error: 0.3633
# Epoch 7507/9999
# ...
